# %%
import matplotlib.pyplot as plt

# %%
activities = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
time_spent = [3, 2, 2, 5]
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']
plt.figure(figsize=(6,6))
plt.pie(
    time_spent,
    labels=activities,
    colors=colors,
    autopct="%1.1f%%",
    startangle=90
)
plt.title("After School Activity")
plt.show()

# %%
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5, 6, 7]  # Days of the week
studying = [3, 4, 3, 5, 4, 3, 4]
playing = [2, 2, 1, 1, 2, 3, 2]
watching_tv = [2, 1, 2, 2, 1, 1, 1]
sleeping = [5, 5, 6, 5, 6, 5, 5]

labels = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']

plt.figure(figsize=(10,6))
plt.stackplot(days, studying, playing, watching_tv, sleeping,
              labels=labels,colors=colors, alpha=0.8)

plt.legend(loc='upper right')  # Location of the legend
plt.title('Weekly Activity Tracker')
plt.xlabel('Day')
plt.ylabel('Hours')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5, 6, 7]  # Days of the week
studying = [8, 7, 8, 6, 8, 4, 2]
playing_cricket = [2, 2, 1, 1, 2, 5, 6]
watching_tv = [2, 1, 2, 2, 1, 1, 1]
sleeping = [7, 8, 6, 6, 6, 5, 5]
mobile=[2,3,5,3,4,2,3]
walk=[2,3,1,2,3,1,3]
travel=[2,2,2,2,2,2,2]
food=[1,1,1,1,1,1,1]

labels = ['Studying', 'Playing Cricket', 'Watching TV', 'Sleeping','Mobile','Walk','Travel','Food']
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral','red','blue','yellow','pink']

plt.figure(figsize=(10,10))
plt.stackplot(days, studying, playing, watching_tv, sleeping,mobile,walk,travel,food,
              labels=labels,colors=colors, alpha=0.8)

plt.legend(loc='upper right')  # Location of the legend
plt.title('Deepchandra Kushwah Weekly Activity Tracker')
plt.xlabel('Days From Monday to Sunday(0-7)')
plt.ylabel('Hours')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

years = [2020, 2021, 2022, 2023]

A = [10, 20, 30, 40]
B = [20, 25, 30, 35]
C = [30, 35, 40, 45]
labels=["Product A", "Product B", "Product C"]
colors=['red','green','pink']
plt.stackplot(years, A, B, C,labels=labels,colors=colors)
plt.legend(loc="upper left")
plt.title("Company Sales")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

years = [2019, 2020, 2021, 2022, 2023]

rohit = [1200, 900, 1000, 1300, 1500]
virat = [1500, 1100, 900, 1400, 1600]
rahul = [800, 1000, 1200, 900, 1100]

plt.figure(figsize=(10,6))

plt.stackplot(
    years,
    rohit,
    virat,
    rahul,
    labels=["Rohit", "Virat", "Rahul"],
    colors=["skyblue", "orange", "green"]
)

plt.title("Runs Contribution Over Years")

plt.xlabel("Year")

plt.ylabel("Runs")

plt.legend(loc="upper left")

plt.grid(alpha=0.3)

plt.show()
