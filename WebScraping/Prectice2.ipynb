# %%
from bs4 import BeautifulSoup

# %%
with open("htmls/page3.html") as f:
    content=f.read()

# %%
soup=BeautifulSoup(content,"html.parser")

# %%
soup.h1
# Out:
# <h1>All products</h1>

# %%
soup.h1.text
# Out:
# 'All products'

# %%
soup.find('p')
# Out:
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>

# %%
soup.find_all('p')
# Out:
# [<p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="price_color">Ã‚Â£57.31</p>,
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>,
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="price_color">Ã‚Â£26.41</p>,
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="price_color">Ã‚Â£47.61</p>,
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>,
# ...

# %%
soup.find('p',class_="star-rating Five")
# Out:
# <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>

# %%
soup.find_all('p',class_="star-rating")
# Out:
# [<p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating One">
#  <i class="icon-star"></i>
# ...

# %%
soup.select_one("p.star-rating Five")
# Out:
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>

# %%
soup.select("p.star-rating")
# Out:
# [<p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating One">
#  <i class="icon-star"></i>
# ...

# %%
soup.find_all("p",class_="star-rating")
# Out:
# [<p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating One">
#  <i class="icon-star"></i>
# ...

# %%
soup.find_all("h3")
# Out:
# [<h3><a href="slow-states-of-collapse-poems_960/index.html" title="Slow States of Collapse: Poems">Slow States of Collapse: ...</a></h3>,
#  <h3><a href="reasons-to-stay-alive_959/index.html" title="Reasons to Stay Alive">Reasons to Stay Alive</a></h3>,
#  <h3><a href="private-paris-private-10_958/index.html" title="Private Paris (Private #10)">Private Paris (Private #10)</a></h3>,
#  <h3><a href="higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957/index.html" title="#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.">#HigherSelfie: Wake Up Your ...</a></h3>,
#  <h3><a href="without-borders-wanderlove-1_956/index.html" title="Without Borders (Wanderlove #1)">Without Borders (Wanderlove #1)</a></h3>,
#  <h3><a href="when-we-collided_955/index.html" title="When We Collided">When We Collided</a></h3>,
#  <h3><a href="we-love-you-charlie-freeman_954/index.html" title="We Love You, Charlie Freeman">We Love You, Charlie ...</a></h3>,
# ...

# %%
soup.p.parent
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="slow-states-of-collapse-poems_960/index.html"><img alt="Slow States of Collapse: Poems" class="thumbnail" src="../media/cache/72/41/72417db983862010ef0c1a25de98c7d7.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="slow-states-of-collapse-poems_960/index.html" title="Slow States of Collapse: Poems">Slow States of Collapse: ...</a></h3>
# <div class="product_price">
# <p class="price_color">Ã‚Â£57.31</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
list(soup.p.children)
# Out:
# ['\n',
#  <i class="icon-star"></i>,
#  '\n',
#  <i class="icon-star"></i>,
#  '\n',
#  <i class="icon-star"></i>,
#  '\n',
#  <i class="icon-star"></i>,
#  '\n',
#  <i class="icon-star"></i>,
#  '\n']

# %%
title_tag=soup.find("h1")
if title_tag:
    print(title_tag.text)
else:
    print("title not found")
# Out:
# All products

# %%
soup.p.find_next_sibling()
# Out:
# <h3><a href="slow-states-of-collapse-poems_960/index.html" title="Slow States of Collapse: Poems">Slow States of Collapse: ...</a></h3>
